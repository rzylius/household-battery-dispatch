# %% [markdown]
# # Household battery dispatch: 15-minute example
# Run this notebook from the repository directory. It uses the same `EnergyOptimizer` as the Python example. Prices and forecasts are synthetic; no live market service is called.
#
# Power inputs are average kW per interval. SOC and cumulative requirements are kWh. Prices are EUR/kWh. See README.md for compatibility, timestamps and the battery efficiency convention.

# %%
# %pip install -r requirements.txt

# %%
from example_15min import run_example
optimizer, series = run_example()

# %%
# Inspect the first hour: four 15-minute intervals.
for index in range(4):
    print(index, {device: {name: float(values[index])
                          for name, values in signals.items()}
                  for device, signals in series.items()})

# %% [markdown]
# For real operation, construct `EnergyOptimizer(n_intervals=len(prices), interval_hours=0.25)` with aligned forecasts and measured initial SOC. Build a fresh optimizer for each replan. Only read dispatch after a successful solve, and execute the appropriate interval through a separately validated hardware controller.
